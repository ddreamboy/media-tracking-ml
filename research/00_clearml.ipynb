# %%
from clearml import Task, Dataset
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
task = Task.init(project_name="MediaTracking", task_name="02_Dataset_Preprocessing")
# Out:
# ClearML Task: created new task id=599c40e8d4564509a6c619fc84eaee7b
# ClearML results page: https://clearml.media-tracking.ru/projects/2f2f27f98fc04685a3e7db98dd1b788d/experiments/599c40e8d4564509a6c619fc84eaee7b/output/log
# 2026-04-03 15:08:16,919 - clearml.Task - INFO - Storing jupyter notebook directly as code

# %%
dataset = Dataset.create(dataset_name="Preprocessed_Posts_300k", dataset_project="MediaTracking")
dataset.add_files(path="data/posts_preprocessed.parquet")
dataset.upload()
dataset.finalize()
print(f"Dataset ID: {dataset.id}")
# Out:
# ClearML results page: https://clearml.media-tracking.ru/projects/93fa36cca5ff4dee88d181ecc8da2538/experiments/be50fd1f13a2451fb87df2456f22268e/output/log
# ClearML dataset page: https://clearml.media-tracking.ru/datasets/simple/93fa36cca5ff4dee88d181ecc8da2538/experiments/be50fd1f13a2451fb87df2456f22268e
# Uploading dataset changes (1 files compressed to 202.46 MiB) to https://files.clearml.media-tracking.ru
# 2026-04-03 15:11:31,383 - clearml.storage - INFO - Uploading: 202.46MB from C:/Users/kadi/AppData/Local/Temp/dataset.be50fd1f13a2451fb87df2456f22268e.irkybiv4.zip
# █████████████████████████████ 100% | 202.46/202.46 MB [00:36<00:00,  5.61MB/s]:
# File compression and upload completed: total size 202.46 MiB, 1 chunk(s) stored (average size 202.46 MiB)
# Dataset ID: be50fd1f13a2451fb87df2456f22268e
